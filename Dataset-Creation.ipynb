# %% [markdown]
# ### Import Necessary Libraries

# %%
from bs4 import BeautifulSoup as bs
import requests
import json
import requests
import urllib
import pickle
import pandas as pd

# %% [markdown]
# ### Load the page given in the URL variable using Requests lib

# %%
url = 'https://en.wikipedia.org/wiki/List_of_Marvel_Cinematic_Universe_films'
r = requests.get(url)
soup = bs(r.text)

# %% [markdown]
# ### Convert the URL into a BeautifulSoup object and remove un-necessary tags

# %%
def clean_tags(soup) :
    for tag in soup.find_all(['sup']) :
        tag.decompose()

def url_bs_object(url) :
    r = requests.get(url)
    soup = bs(r.text)
    clean_tags(soup)
    info_box = soup.find('table',class_='infobox vevent')
    info_rows = info_box.find_all('tr')    
    
    return info_rows

# %%
def get_content_value(row) :
    if row.find(class_='plainlist') :
        return [li.get_text(strip=True,separator=' ').replace(u'\xa0',u' ') for li in row.find_all('li')]
    
    return row.find('td').get_text(strip=True,separator=' ').replace(u'\xa0',u' ')

# %% [markdown]
# ### Dump the data scrapped from the info box into a dictionary

# %%
def insert_content_dict(info_rows) :
    movie_info = {} # this dictionary will store all the info of a particular movie
    for index,row in enumerate(info_rows) :
        if index == 0 :
            movie_info['title'] = row.find('th').get_text(strip=True)
        elif index == 1 :
            continue
        else :
            movie_info[row.find('th').get_text(strip=True,separator=' ')] = get_content_value(row)  
    return movie_info

# %% [markdown]
# ### Scrap Info Box for all movies in List of 'List of Marvel Cinematic Universe films' and append in 'movies' list

# %%
movie_info_list = []
base_url = 'https://en.wikipedia.org'
table = soup.find('table',class_='wikitable plainrowheaders')
movie_rows = table.find_all('tr')
for row in movie_rows :
    try :
        relative_url = row.find('i').a['href']
        url = base_url + relative_url
        info_rows = url_bs_object(url)
        movie_info = insert_content_dict(info_rows)
        movie_info_list.append(movie_info)
    except Exception as e :
        pass

movie_info_list
# Out:
# [{'title': 'Iron Man',
#   'Directed by': 'Jon Favreau',
#   'Produced by': ['Avi Arad', 'Kevin Feige'],
#   'Screenplay by': ['Mark Fergus Hawk Ostby', 'Art Marcum Matt Holloway'],
#   'Based on': ['Stan Lee', 'Larry Lieber', 'Don Heck', 'Jack Kirby'],
#   'Starring': ['Robert Downey Jr.',
#    'Terrence Howard',
#    'Jeff Bridges',
#    'Shaun Toub',
#    'Gwyneth Paltrow'],
#   'Music by': 'Ramin Djawadi',
#   'Cinematography': 'Matthew Libatique',
#   'Edited by': 'Dan Lebental',
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Paramount Pictures',
#   'Release date': ['April 14, 2008 ( 2008-04-14 ) (Sydney)',
#    'May 2, 2008 ( 2008-05-02 ) (United States)'],
#   'Running time': '126 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$140 million',
#   'Box office': '$585.3 million'},
#  {'title': 'The Incredible Hulk',
#   'Directed by': 'Louis Leterrier',
#   'Produced by': ['Avi Arad', 'Gale Anne Hurd', 'Kevin Feige'],
#   'Written by': 'Zak Penn',
#   'Based on': ['Stan Lee', 'Jack Kirby'],
#   'Starring': ['Edward Norton',
#    'Liv Tyler',
#    'Tim Roth',
#    'Tim Blake Nelson',
#    'Ty Burrell',
#    'William Hurt'],
#   'Music by': 'Craig Armstrong',
#   'Cinematography': 'Peter Menzies Jr.',
#   'Edited by': ['John Wright', 'Rick Shaine', 'Vincent Tabaillon'],
#   'Production company': ['Marvel Studios', 'Valhalla Motion Pictures'],
#   'Distributed by': 'Universal Pictures',
#   'Release date': ['June 8, 2008 ( 2008-06-08 ) ( Gibson Amphitheatre )',
#    'June 13, 2008 ( 2008-06-13 ) (United States)'],
#   'Running time': '112 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$150 million',
#   'Box office': '$264.8 million'},
#  {'title': 'Iron Man 2',
#   'Directed by': 'Jon Favreau',
#   'Produced by': 'Kevin Feige',
#   'Written by': 'Justin Theroux',
#   'Based on': ['Stan Lee', 'Larry Lieber', 'Don Heck', 'Jack Kirby'],
#   'Starring': ['Robert Downey Jr.',
#    'Gwyneth Paltrow',
#    'Don Cheadle',
#    'Scarlett Johansson',
#    'Sam Rockwell',
#    'Mickey Rourke',
#    'Samuel L. Jackson'],
#   'Music by': 'John Debney',
#   'Cinematography': 'Matthew Libatique',
#   'Edited by': ['Dan Lebental', 'Richard Pearson'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Paramount Pictures',
#   'Release date': ['April 26, 2010 ( 2010-04-26 ) ( El Capitan Theatre )',
#    'May 7, 2010 ( 2010-05-07 ) (United States)'],
#   'Running time': '124 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$170–200 million',
#   'Box office': '$623.9 million'},
#  {'title': 'Captain America: The First Avenger',
#   'Directed by': 'Joe Johnston',
#   'Produced by': 'Kevin Feige',
#   'Screenplay by': 'Christopher Markus Stephen McFeely',
#   'Based on': ['Joe Simon', 'Jack Kirby'],
#   'Starring': ['Chris Evans',
#    'Tommy Lee Jones',
#    'Hugo Weaving',
#    'Hayley Atwell',
#    'Sebastian Stan',
#    'Dominic Cooper',
#    'Neal McDonough',
#    'Derek Luke',
#    'Stanley Tucci'],
#   'Music by': 'Alan Silvestri',
#   'Cinematography': 'Shelly Johnson',
#   'Edited by': ['Jeffrey Ford', 'Robert Dalva'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Paramount Pictures',
#   'Release date': ['July 19, 2011 ( 2011-07-19 ) ( El Capitan Theatre )',
#    'July 22, 2011 ( 2011-07-22 ) (United States)'],
#   'Running time': '124 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$140–216.7 million',
#   'Box office': '$370.6 million'},
#  {'title': 'The Avengers',
#   'Directed by': 'Joss Whedon',
#   'Produced by': 'Kevin Feige',
#   'Screenplay by': 'Joss Whedon',
#   'Story by': ['Zak Penn', 'Joss Whedon'],
#   'Based on': ['Stan Lee', 'Jack Kirby'],
#   'Starring': ['Robert Downey Jr.',
#    'Chris Evans',
#    'Mark Ruffalo',
#    'Chris Hemsworth',
#    'Scarlett Johansson',
#    'Jeremy Renner',
#    'Tom Hiddleston',
#    'Clark Gregg',
#    'Cobie Smulders',
#    'Stellan Skarsgård',
#    'Samuel L. Jackson'],
#   'Music by': 'Alan Silvestri',
#   'Cinematography': 'Seamus McGarvey',
#   'Edited by': ['Jeffrey Ford', 'Lisa Lassek'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release date': ['April 11, 2012 ( 2012-04-11 ) ( El Capitan Theatre )',
#    'May 4, 2012 ( 2012-05-04 ) (United States)'],
#   'Running time': '143 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$220 million',
#   'Box office': '$1.519 billion'},
#  {'title': 'Iron Man 3',
#   'Directed by': 'Shane Black',
#   'Produced by': 'Kevin Feige',
#   'Screenplay by': ['Shane Black', 'Drew Pearce'],
#   'Based on': ['Stan Lee', 'Don Heck', 'Larry Lieber', 'Jack Kirby'],
#   'Starring': ['Robert Downey Jr.',
#    'Gwyneth Paltrow',
#    'Don Cheadle',
#    'Guy Pearce',
#    'Rebecca Hall',
#    'Stéphanie Szostak',
#    'James Badge Dale',
#    'Jon Favreau',
#    'Ben Kingsley'],
#   'Music by': 'Brian Tyler',
#   'Cinematography': 'John Toll',
#   'Edited by': ['Jeffrey Ford', 'Peter S. Elliot'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release date': ['April 14, 2013 ( 2013-04-14 ) ( Grand Rex )',
#    'May 3, 2013 ( 2013-05-03 ) (United States)'],
#   'Running time': '131 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$200 million',
#   'Box office': '$1.215 billion'},
#  {'title': 'Thor: The Dark World',
#   'Directed by': 'Alan Taylor',
#   'Produced by': 'Kevin Feige',
#   'Screenplay by': ['Christopher Yost', 'Christopher Markus Stephen McFeely'],
#   'Story by': ['Don Payne', 'Robert Rodat'],
#   'Based on': ['Stan Lee', 'Larry Lieber', 'Jack Kirby'],
#   'Starring': ['Chris Hemsworth',
#    'Natalie Portman',
#    'Tom Hiddleston',
#    'Anthony Hopkins',
#    'Stellan Skarsgård',
#    'Idris Elba',
#    'Christopher Eccleston',
#    'Adewale Akinnuoye-Agbaje',
#    'Kat Dennings',
#    'Ray Stevenson',
#    'Zachary Levi',
#    'Tadanobu Asano',
#    'Jaimie Alexander',
#    'Rene Russo'],
#   'Music by': 'Brian Tyler',
#   'Cinematography': 'Kramer Morgenthau',
#   'Edited by': ['Dan Lebental', 'Wyatt Smith'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release date': ['October 22, 2013 ( 2013-10-22 ) ( Leicester Square )',
#    'November 8, 2013 ( 2013-11-08 ) (United States)'],
#   'Running time': '112 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$170 million',
#   'Box office': '$644.8 million'},
#  {'title': 'Captain America: The Winter Soldier',
#   'Directed by': ['Anthony Russo', 'Joe Russo'],
#   'Produced by': 'Kevin Feige',
#   'Screenplay by': ['Christopher Markus', 'Stephen McFeely'],
#   'Based on': ['Joe Simon', 'Jack Kirby'],
#   'Starring': ['Chris Evans',
#    'Scarlett Johansson',
#    'Sebastian Stan',
#    'Anthony Mackie',
#    'Cobie Smulders',
#    'Frank Grillo',
#    'Emily VanCamp',
#    'Hayley Atwell',
#    'Robert Redford',
#    'Samuel L. Jackson'],
#   'Music by': 'Henry Jackman',
#   'Cinematography': 'Trent Opaloch',
#   'Edited by': ['Jeffrey Ford', 'Matthew Schmidt'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release date': ['March 13, 2014 ( 2014-03-13 ) ( El Capitan Theatre )',
#    'April 4, 2014 ( 2014-04-04 ) (United States)'],
#   'Running time': '136 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$170–177 million',
#   'Box office': '$714.4 million'},
#  {'title': 'Avengers: Age of Ultron',
#   'Directed by': 'Joss Whedon',
#   'Produced by': 'Kevin Feige',
#   'Written by': 'Joss Whedon',
#   'Based on': ['Stan Lee', 'Jack Kirby'],
#   'Starring': ['Robert Downey Jr.',
#    'Chris Hemsworth',
#    'Mark Ruffalo',
#    'Chris Evans',
#    'Scarlett Johansson',
#    'Jeremy Renner',
#    'Don Cheadle',
#    'Aaron Taylor-Johnson',
#    'Elizabeth Olsen',
#    'Paul Bettany',
#    'Cobie Smulders',
#    'Anthony Mackie',
#    'Hayley Atwell',
#    'Idris Elba',
#    'Stellan Skarsgård',
#    'James Spader',
#    'Samuel L. Jackson'],
#   'Music by': ['Brian Tyler', 'Danny Elfman'],
#   'Cinematography': 'Ben Davis',
#   'Edited by': ['Jeffrey Ford', 'Lisa Lassek'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release date': ['April 13, 2015 ( 2015-04-13 ) ( Dolby Theatre )',
#    'May 1, 2015 ( 2015-05-01 ) (United States)'],
#   'Running time': '141 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': ['$444–495.2 million (gross)', '$365.5 million (net)'],
#   'Box office': '$1.403 billion'},
#  {'title': 'Ant-Man',
#   'Directed by': 'Peyton Reed',
#   'Produced by': 'Kevin Feige',
#   'Screenplay by': ['Edgar Wright', 'Joe Cornish', 'Adam McKay', 'Paul Rudd'],
#   'Story by': ['Edgar Wright', 'Joe Cornish'],
#   'Based on': ['Stan Lee', 'Larry Lieber', 'Jack Kirby'],
#   'Starring': ['Paul Rudd',
#    'Evangeline Lilly',
#    'Corey Stoll',
#    'Bobby Cannavale',
#    'Michael Peña',
#    'Tip "T.I." Harris',
#    'Anthony Mackie',
#    'Wood Harris',
#    'Judy Greer',
#    'David Dastmalchian',
#    'Michael Douglas'],
#   'Music by': 'Christophe Beck',
#   'Cinematography': 'Russell Carpenter',
#   'Edited by': ['Dan Lebental', 'Colby Parker, Jr.'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release date': ['June 29, 2015 ( 2015-06-29 ) ( Dolby Theatre )',
#    'July 17, 2015 ( 2015-07-17 ) (United States)'],
#   'Running time': '117 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$130–169.3 million',
#   'Box office': '$519.3 million'},
#  {'title': 'Captain America: Civil War',
#   'Directed by': ['Anthony Russo Joe Russo', 'Anthony Russo', 'Joe Russo'],
#   'Produced by': 'Kevin Feige',
#   'Screenplay by': ['Christopher Markus Stephen McFeely',
#    'Christopher Markus',
#    'Stephen McFeely'],
#   'Based on': ['Joe Simon', 'Jack Kirby'],
#   'Starring': ['Chris Evans',
#    'Robert Downey Jr.',
#    'Scarlett Johansson',
#    'Sebastian Stan',
#    'Anthony Mackie',
#    'Don Cheadle',
#    'Jeremy Renner',
#    'Chadwick Boseman',
#    'Paul Bettany',
#    'Elizabeth Olsen',
#    'Paul Rudd',
#    'Emily VanCamp',
#    'Tom Holland',
#    'Frank Grillo',
#    'William Hurt',
#    'Daniel Brühl'],
#   'Music by': 'Henry Jackman',
#   'Cinematography': 'Trent Opaloch',
#   'Edited by': ['Jeffrey Ford', 'Matthew Schmidt'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release date': ['April 12, 2016 ( 2016-04-12 ) ( Dolby Theatre )',
#    'May 6, 2016 ( 2016-05-06 ) (United States)'],
#   'Running time': '147 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$250 million',
#   'Box office': '$1.153 billion'},
#  {'title': 'Doctor Strange',
#   'Directed by': 'Scott Derrickson',
#   'Produced by': 'Kevin Feige',
#   'Written by': ['Jon Spaihts', 'Scott Derrickson', 'C. Robert Cargill'],
#   'Based on': ['Stan Lee', 'Steve Ditko'],
#   'Starring': ['Benedict Cumberbatch',
#    'Chiwetel Ejiofor',
#    'Rachel McAdams',
#    'Benedict Wong',
#    'Michael Stuhlbarg',
#    'Benjamin Bratt',
#    'Scott Adkins',
#    'Mads Mikkelsen',
#    'Tilda Swinton'],
#   'Music by': 'Michael Giacchino',
#   'Cinematography': 'Ben Davis',
#   'Edited by': ['Wyatt Smith', 'Sabrina Plisco'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release date': ['October 13, 2016 ( 2016-10-13 ) ( Hong Kong )',
#    'November 4, 2016 ( 2016-11-04 ) (United States)'],
#   'Running time': '115 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$165–236.6 million',
#   'Box office': '$677.7 million'},
#  {'title': 'Guardians of the Galaxy Vol. 2',
#   'Directed by': 'James Gunn',
#   'Produced by': 'Kevin Feige',
#   'Written by': 'James Gunn',
#   'Based on': ['Dan Abnett', 'Andy Lanning'],
#   'Starring': ['Chris Pratt',
#    'Zoe Saldana',
#    'Dave Bautista',
#    'Vin Diesel',
#    'Bradley Cooper',
#    'Michael Rooker',
#    'Karen Gillan',
#    'Pom Klementieff',
#    'Elizabeth Debicki',
#    'Chris Sullivan',
#    'Sean Gunn',
#    'Sylvester Stallone',
#    'Kurt Russell'],
#   'Music by': 'Tyler Bates',
#   'Cinematography': 'Henry Braham',
#   'Edited by': ['Fred Raskin', 'Craig Wood'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release date': ['April 10, 2017 ( 2017-04-10 ) ( Tokyo )',
#    'May 5, 2017 ( 2017-05-05 ) (United States)'],
#   'Running time': '137 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$200 million',
#   'Box office': '$863.8 million'},
#  {'title': 'Spider-Man: Homecoming',
#   'Directed by': 'Jon Watts',
#   'Produced by': ['Kevin Feige', 'Amy Pascal'],
#   'Screenplay by': ['Jonathan Goldstein',
#    'John Francis Daley',
#    'Jon Watts',
#    'Christopher Ford',
#    'Chris McKenna',
#    'Erik Sommers'],
#   'Story by': ['Jonathan Goldstein', 'John Francis Daley'],
#   'Based on': ['Stan Lee', 'Steve Ditko'],
#   'Starring': ['Tom Holland',
#    'Michael Keaton',
#    'Jon Favreau',
#    'Gwyneth Paltrow',
#    'Zendaya',
#    'Donald Glover',
#    'Jacob Batalon',
#    'Laura Harrier',
#    'Tony Revolori',
#    'Bokeem Woodbine',
#    'Tyne Daly',
#    'Marisa Tomei',
#    'Robert Downey Jr.'],
#   'Music by': 'Michael Giacchino',
#   'Cinematography': 'Salvatore Totino',
#   'Edited by': ['Dan Lebental', 'Debbie Berman'],
#   'Production companies': ['Columbia Pictures',
#    'Marvel Studios',
#    'Pascal Pictures'],
#   'Distributed by': 'Sony Pictures Releasing',
#   'Release date': ['June 28, 2017 ( 2017-06-28 ) (Hollywood)',
#    'July 7, 2017 ( 2017-07-07 ) (United States)'],
#   'Running time': '133 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$175 million',
#   'Box office': '$880.2 million'},
#  {'title': 'Thor: Ragnarok',
#   'Directed by': 'Taika Waititi',
#   'Produced by': 'Kevin Feige',
#   'Written by': ['Eric Pearson', 'Craig Kyle', 'Christopher L. Yost'],
#   'Based on': ['Stan Lee', 'Larry Lieber', 'Jack Kirby'],
#   'Starring': ['Chris Hemsworth',
#    'Tom Hiddleston',
#    'Cate Blanchett',
#    'Idris Elba',
#    'Jeff Goldblum',
#    'Tessa Thompson',
#    'Karl Urban',
#    'Mark Ruffalo',
#    'Anthony Hopkins'],
#   'Music by': 'Mark Mothersbaugh',
#   'Cinematography': 'Javier Aguirresarobe',
#   'Edited by': ['Joel Negron', 'Zene Baker'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release date': ['October 10, 2017 ( 2017-10-10 ) ( El Capitan Theatre )',
#    'November 3, 2017 ( 2017-11-03 ) (United States)'],
#   'Running time': '130 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$180 million',
#   'Box office': '$854 million'},
#  {'title': 'Black Panther',
#   'Directed by': 'Ryan Coogler',
#   'Produced by': 'Kevin Feige',
#   'Written by': ['Ryan Coogler', 'Joe Robert Cole'],
#   'Based on': ['Stan Lee', 'Jack Kirby'],
#   'Starring': ['Chadwick Boseman',
#    'Michael B. Jordan',
#    "Lupita Nyong'o",
#    'Danai Gurira',
#    'Martin Freeman',
#    'Daniel Kaluuya',
#    'Letitia Wright',
#    'Winston Duke',
#    'Angela Bassett',
#    'Forest Whitaker',
#    'Andy Serkis'],
#   'Music by': 'Ludwig Göransson',
#   'Cinematography': 'Rachel Morrison',
#   'Edited by': ['Michael P. Shawver', 'Debbie Berman'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release date': ['January 29, 2018 ( 2018-01-29 ) ( Dolby Theatre )',
#    'February 16, 2018 ( 2018-02-16 ) (United States)'],
#   'Running time': '134 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$200 million',
#   'Box office': '$1.347 billion'},
#  {'title': 'Avengers: Infinity War',
#   'Directed by': ['Anthony Russo', 'Joe Russo'],
#   'Produced by': 'Kevin Feige',
#   'Screenplay by': ['Christopher Markus', 'Stephen McFeely'],
#   'Based on': ['Stan Lee', 'Jack Kirby'],
#   'Starring': ['Robert Downey Jr.',
#    'Chris Hemsworth',
#    'Mark Ruffalo',
#    'Chris Evans',
#    'Scarlett Johansson',
#    'Benedict Cumberbatch',
#    'Don Cheadle',
#    'Tom Holland',
#    'Chadwick Boseman',
#    'Paul Bettany',
#    'Elizabeth Olsen',
#    'Anthony Mackie',
#    'Sebastian Stan',
#    'Danai Gurira',
#    'Letitia Wright',
#    'Dave Bautista',
#    'Zoe Saldana',
#    'Josh Brolin',
#    'Chris Pratt'],
#   'Music by': 'Alan Silvestri',
#   'Cinematography': 'Trent Opaloch',
#   'Edited by': ['Jeffrey Ford', 'Matthew Schmidt'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release date': ['April 23, 2018 ( 2018-04-23 ) ( Dolby Theatre )',
#    'April 27, 2018 ( 2018-04-27 ) (United States)'],
#   'Running time': '149 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$316–400 million',
#   'Box office': '$2.048 billion'},
#  {'title': 'Ant-Man and the Wasp',
#   'Directed by': 'Peyton Reed',
#   'Produced by': ['Kevin Feige', 'Stephen Broussard'],
#   'Written by': ['Chris McKenna',
#    'Erik Sommers',
#    'Paul Rudd',
#    'Andrew Barrer',
#    'Gabriel Ferrari'],
#   'Based on': ['Ant-Man by Stan Lee Larry Lieber Jack Kirby',
#    'Stan Lee',
#    'Larry Lieber',
#    'Jack Kirby',
#    'Wasp by Stan Lee Ernie Hart Jack Kirby',
#    'Stan Lee',
#    'Ernie Hart',
#    'Jack Kirby'],
#   'Starring': ['Paul Rudd',
#    'Evangeline Lilly',
#    'Michael Peña',
#    'Walton Goggins',
#    'Bobby Cannavale',
#    'Judy Greer',
#    'Tip "T.I." Harris',
#    'David Dastmalchian',
#    'Hannah John-Kamen',
#    'Abby Ryder Fortson',
#    'Randall Park',
#    'Michelle Pfeiffer',
#    'Laurence Fishburne',
#    'Michael Douglas'],
#   'Music by': 'Christophe Beck',
#   'Cinematography': 'Dante Spinotti',
#   'Edited by': ['Dan Lebental', 'Craig Wood'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release date': ['June 25, 2018 ( 2018-06-25 ) ( El Capitan Theatre )',
#    'July 6, 2018 ( 2018-07-06 ) (United States)'],
#   'Running time': '118 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$162–195 million',
#   'Box office': '$622.7 million'},
#  {'title': 'Captain Marvel',
#   'Directed by': ['Anna Boden', 'Ryan Fleck'],
#   'Produced by': 'Kevin Feige',
#   'Screenplay by': ['Anna Boden', 'Ryan Fleck', 'Geneva Robertson-Dworet'],
#   'Story by': ['Nicole Perlman',
#    'Meg LeFauve',
#    'Anna Boden',
#    'Ryan Fleck',
#    'Geneva Robertson-Dworet'],
#   'Based on': ['Captain Marvel by Stan Lee Gene Colan',
#    'Stan Lee',
#    'Gene Colan',
#    'Carol Danvers by Roy Thomas Gene Colan',
#    'Roy Thomas',
#    'Gene Colan'],
#   'Starring': ['Brie Larson',
#    'Samuel L. Jackson',
#    'Ben Mendelsohn',
#    'Djimon Hounsou',
#    'Lee Pace',
#    'Lashana Lynch',
#    'Gemma Chan',
#    'Annette Bening',
#    'Clark Gregg',
#    'Jude Law'],
#   'Music by': 'Pinar Toprak',
#   'Cinematography': 'Ben Davis',
#   'Edited by': ['Elliot Graham', 'Debbie Berman'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release date': ['February 27, 2019 ( 2019-02-27 ) (London)',
#    'March 8, 2019 ( 2019-03-08 ) (United States)'],
#   'Running time': '124 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$152–175 million',
#   'Box office': '$1.128 billion'},
#  {'title': 'Avengers: Endgame',
#   'Directed by': ['Anthony Russo', 'Joe Russo'],
#   'Produced by': 'Kevin Feige',
#   'Screenplay by': ['Christopher Markus', 'Stephen McFeely'],
#   'Based on': ['Stan Lee', 'Jack Kirby'],
#   'Starring': ['Robert Downey Jr.',
#    'Chris Evans',
#    'Mark Ruffalo',
#    'Chris Hemsworth',
#    'Scarlett Johansson',
#    'Jeremy Renner',
#    'Don Cheadle',
#    'Paul Rudd',
#    'Brie Larson',
#    'Karen Gillan',
#    'Danai Gurira',
#    'Benedict Wong',
#    'Jon Favreau',
#    'Bradley Cooper',
#    'Gwyneth Paltrow',
#    'Josh Brolin'],
#   'Music by': 'Alan Silvestri',
#   'Cinematography': 'Trent Opaloch',
#   'Edited by': ['Jeffrey Ford', 'Matthew Schmidt'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release date': ['April 22, 2019 ( 2019-04-22 ) ( Los Angeles Convention Center )',
#    'April 26, 2019 ( 2019-04-26 ) (United States)'],
#   'Running time': '181 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$356 million',
#   'Box office': '$2.798 billion'},
#  {'title': 'Spider-Man: Far From Home',
#   'Directed by': 'Jon Watts',
#   'Produced by': ['Kevin Feige', 'Amy Pascal'],
#   'Written by': ['Chris McKenna', 'Erik Sommers'],
#   'Based on': ['Stan Lee', 'Steve Ditko'],
#   'Starring': ['Tom Holland',
#    'Samuel L. Jackson',
#    'Zendaya',
#    'Cobie Smulders',
#    'Jon Favreau',
#    'J. B. Smoove',
#    'Jacob Batalon',
#    'Martin Starr',
#    'Marisa Tomei',
#    'Jake Gyllenhaal'],
#   'Music by': 'Michael Giacchino',
#   'Cinematography': 'Matthew J. Lloyd',
#   'Edited by': ['Dan Lebental', 'Leigh Folsom Boyd'],
#   'Production companies': ['Columbia Pictures',
#    'Marvel Studios',
#    'Pascal Pictures'],
#   'Distributed by': 'Sony Pictures Releasing',
#   'Release date': ['June 26, 2019 ( 2019-06-26 ) ( TCL Chinese Theatre )',
#    'July 2, 2019 ( 2019-07-02 ) (United States)'],
#   'Running time': '129 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$160 million',
#   'Box office': '$1.132 billion'}]

# %% [markdown]
# ### Convert the "Running Time" into Integer and "Release Date" into date format

# %%
for movie in movie_info_list :
    movie['Running time'] = int(movie['Running time'].split(' ')[0])
    movie['Release date'] = movie['Release date'][0].split('(')[0]

# %% [markdown]
# ### Convert the Box Office into float numbers, all in the scale of MILLION

# %%
def boxofice_into_num(box_office) :
    amount,scale = box_office.strip().split(' ')
    if scale.startswith('billion') :
        return float(amount[1:])*1000
    return float(amount[1:])

for movie in movie_info_list :
    movie['Box office'] = boxofice_into_num(movie['Box office'])
    movie['Box Office (USD Millions)'] = movie.pop('Box office')

# %% [markdown]
# ### Save/Reload Movie Data

# %%
def save_data(file,data) :
    with open(file, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

# %%
def load_data(file) :
    with open(file) as f :
        data = json.load(f)
    return data

# %%
save_data('marvel_movie_data.json',movie_info_list)

# %%
movie_info_list = load_data('marvel_movie_data.json')

# %% [markdown]
# ### Convert Budget into float numbers all in scale of MILLION

# %%
def budget_into_num(budget) :
    if isinstance(budget,list) :
        budget = budget[0]
    try:
        budget = float(budget.replace(u'â€“',u' ').split(' ')[0][1:])
    except:
        budget = float(budget.replace('-',' ').split(' ')[0][1:])
    return budget

# %%
for movie in movie_info_list :
    budget = budget_into_num(movie['Budget'])
    movie['Budget'] = budget
    movie['Budget (USD Millions)'] = movie.pop('Budget')

# %% [markdown]
# ### Convert Release date into a Date object

# %%
from datetime import datetime
for movie in movie_info_list :
    movie['Release date'] = datetime.strptime(movie['Release date'], '%B %d, %Y ')

# %% [markdown]
# ### Saving our data again in .Pickle format

# %%
def save_pickle(file) :
    with open(file, 'wb') as handle:
        pickle.dump(movie_info_list, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
def load_pickle(file) :
    with open('marvel_movie_data_final.pickle', 'rb') as handle:
        movie_info_list = pickle.load(handle)
    return movie_info_list

# %%
save_pickle('marvel_movie_data_final.pickle')

# %%
movie_info_list = load_pickle('marvel_movie_data_final.pickle')

# %% [markdown]
# ### Attach IMDB, Metascore/Rotten Tomatoes scores to dataset

# %%
def get_omdb_info(title) :
    
    base_url = 'http://www.omdbapi.com/?'
    parameters = {'apikey':'ef11ad99','t':title}
    params_encoded = urllib.parse.urlencode(parameters)
    full_url = base_url + params_encoded
    return requests.get(full_url).json()

def get_rotten_tomato(omdb_info) :
    ratings = omdb_info.get('Ratings',[])
    for rating in ratings :
        if rating['Source'] == 'Rotten Tomatoes' :
            return rating['Value']
    return None

# %%
for movie in movie_info_list :
    title = movie['title']
    omdb_info = get_omdb_info(title)
    movie['imdbRating'] = omdb_info.get('imdbRating',None)
    movie['Metascore'] = omdb_info.get('Metascore',None)
    movie['Rotten Tomatoes'] = get_rotten_tomato(omdb_info)

# %%
save_pickle('marvel_movie_data_final.pickle')

# %%
movie_info_list = load_pickle('marvel_movie_data_final.pickle')

# %%
movie_info_list
# Out:
# [{'title': 'Iron Man',
#   'Directed by': 'Jon Favreau',
#   'Produced by': ['Avi Arad', 'Kevin Feige'],
#   'Screenplay by': ['Mark Fergus Hawk Ostby', 'Art Marcum Matt Holloway'],
#   'Based on': ['Stan Lee', 'Larry Lieber', 'Don Heck', 'Jack Kirby'],
#   'Starring': ['Robert Downey Jr.',
#    'Terrence Howard',
#    'Jeff Bridges',
#    'Shaun Toub',
#    'Gwyneth Paltrow'],
#   'Music by': 'Ramin Djawadi',
#   'Cinematography': 'Matthew Libatique',
#   'Edited by': 'Dan Lebental',
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Paramount Pictures',
#   'Release date': datetime.datetime(2008, 4, 14, 0, 0),
#   'Running time': 126,
#   'Country': 'United States',
#   'Language': 'English',
#   'Box Office (USD Millions)': 585.3,
#   'Budget (USD Millions)': 140.0,
#   'imdbRating': '7.9',
#   'Metascore': '79',
#   'Rotten Tomatoes': '94%'},
#  {'title': 'The Incredible Hulk',
#   'Directed by': 'Louis Leterrier',
#   'Produced by': ['Avi Arad', 'Gale Anne Hurd', 'Kevin Feige'],
#   'Written by': 'Zak Penn',
#   'Based on': ['Stan Lee', 'Jack Kirby'],
#   'Starring': ['Edward Norton',
#    'Liv Tyler',
#    'Tim Roth',
#    'Tim Blake Nelson',
#    'Ty Burrell',
#    'William Hurt'],
#   'Music by': 'Craig Armstrong',
#   'Cinematography': 'Peter Menzies Jr.',
#   'Edited by': ['John Wright', 'Rick Shaine', 'Vincent Tabaillon'],
#   'Production company': ['Marvel Studios', 'Valhalla Motion Pictures'],
#   'Distributed by': 'Universal Pictures',
#   'Release date': datetime.datetime(2008, 6, 8, 0, 0),
#   'Running time': 112,
#   'Country': 'United States',
#   'Language': 'English',
#   'Box Office (USD Millions)': 264.8,
#   'Budget (USD Millions)': 150.0,
#   'imdbRating': '6.7',
#   'Metascore': '61',
#   'Rotten Tomatoes': '67%'},
#  {'title': 'Iron Man 2',
#   'Directed by': 'Jon Favreau',
#   'Produced by': 'Kevin Feige',
#   'Written by': 'Justin Theroux',
#   'Based on': ['Stan Lee', 'Larry Lieber', 'Don Heck', 'Jack Kirby'],
#   'Starring': ['Robert Downey Jr.',
#    'Gwyneth Paltrow',
#    'Don Cheadle',
#    'Scarlett Johansson',
#    'Sam Rockwell',
#    'Mickey Rourke',
#    'Samuel L. Jackson'],
#   'Music by': 'John Debney',
#   'Cinematography': 'Matthew Libatique',
#   'Edited by': ['Dan Lebental', 'Richard Pearson'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Paramount Pictures',
#   'Release date': datetime.datetime(2010, 4, 26, 0, 0),
#   'Running time': 124,
#   'Country': 'United States',
#   'Language': 'English',
#   'Box Office (USD Millions)': 623.9,
#   'Budget (USD Millions)': 170.0,
#   'imdbRating': '7.0',
#   'Metascore': '57',
#   'Rotten Tomatoes': '72%'},
#  {'title': 'Captain America: The First Avenger',
#   'Directed by': 'Joe Johnston',
#   'Produced by': 'Kevin Feige',
#   'Screenplay by': 'Christopher Markus Stephen McFeely',
#   'Based on': ['Joe Simon', 'Jack Kirby'],
#   'Starring': ['Chris Evans',
#    'Tommy Lee Jones',
#    'Hugo Weaving',
#    'Hayley Atwell',
#    'Sebastian Stan',
#    'Dominic Cooper',
#    'Neal McDonough',
#    'Derek Luke',
#    'Stanley Tucci'],
#   'Music by': 'Alan Silvestri',
#   'Cinematography': 'Shelly Johnson',
#   'Edited by': ['Jeffrey Ford', 'Robert Dalva'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Paramount Pictures',
#   'Release date': datetime.datetime(2011, 7, 19, 0, 0),
#   'Running time': 124,
#   'Country': 'United States',
#   'Language': 'English',
#   'Box Office (USD Millions)': 370.6,
#   'Budget (USD Millions)': 140.0,
#   'imdbRating': '6.9',
#   'Metascore': '66',
#   'Rotten Tomatoes': '80%'},
#  {'title': 'The Avengers',
#   'Directed by': 'Joss Whedon',
#   'Produced by': 'Kevin Feige',
#   'Screenplay by': 'Joss Whedon',
#   'Story by': ['Zak Penn', 'Joss Whedon'],
#   'Based on': ['Stan Lee', 'Jack Kirby'],
#   'Starring': ['Robert Downey Jr.',
#    'Chris Evans',
#    'Mark Ruffalo',
#    'Chris Hemsworth',
#    'Scarlett Johansson',
#    'Jeremy Renner',
#    'Tom Hiddleston',
#    'Clark Gregg',
#    'Cobie Smulders',
#    'Stellan SkarsgÃ¥rd',
#    'Samuel L. Jackson'],
#   'Music by': 'Alan Silvestri',
#   'Cinematography': 'Seamus McGarvey',
#   'Edited by': ['Jeffrey Ford', 'Lisa Lassek'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release date': datetime.datetime(2012, 4, 11, 0, 0),
#   'Running time': 143,
#   'Country': 'United States',
#   'Language': 'English',
#   'Box Office (USD Millions)': 1519.0,
#   'Budget (USD Millions)': 220.0,
#   'imdbRating': '8.0',
#   'Metascore': '69',
#   'Rotten Tomatoes': '92%'},
#  {'title': 'Iron Man 3',
#   'Directed by': 'Shane Black',
#   'Produced by': 'Kevin Feige',
#   'Screenplay by': ['Shane Black', 'Drew Pearce'],
#   'Based on': ['Stan Lee', 'Don Heck', 'Larry Lieber', 'Jack Kirby'],
#   'Starring': ['Robert Downey Jr.',
#    'Gwyneth Paltrow',
#    'Don Cheadle',
#    'Guy Pearce',
#    'Rebecca Hall',
#    'StÃ©phanie Szostak',
#    'James Badge Dale',
#    'Jon Favreau',
#    'Ben Kingsley'],
#   'Music by': 'Brian Tyler',
#   'Cinematography': 'John Toll',
#   'Edited by': ['Jeffrey Ford', 'Peter S. Elliot'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release date': datetime.datetime(2013, 4, 14, 0, 0),
#   'Running time': 131,
#   'Country': 'United States',
#   'Language': 'English',
#   'Box Office (USD Millions)': 1215.0,
#   'Budget (USD Millions)': 200.0,
#   'imdbRating': '7.2',
#   'Metascore': '62',
#   'Rotten Tomatoes': '79%'},
#  {'title': 'Thor: The Dark World',
#   'Directed by': 'Alan Taylor',
#   'Produced by': 'Kevin Feige',
#   'Screenplay by': ['Christopher Yost', 'Christopher Markus Stephen McFeely'],
#   'Story by': ['Don Payne', 'Robert Rodat'],
#   'Based on': ['Stan Lee', 'Larry Lieber', 'Jack Kirby'],
#   'Starring': ['Chris Hemsworth',
#    'Natalie Portman',
#    'Tom Hiddleston',
#    'Anthony Hopkins',
#    'Stellan SkarsgÃ¥rd',
#    'Idris Elba',
#    'Christopher Eccleston',
#    'Adewale Akinnuoye-Agbaje',
#    'Kat Dennings',
#    'Ray Stevenson',
#    'Zachary Levi',
#    'Tadanobu Asano',
#    'Jaimie Alexander',
#    'Rene Russo'],
#   'Music by': 'Brian Tyler',
#   'Cinematography': 'Kramer Morgenthau',
#   'Edited by': ['Dan Lebental', 'Wyatt Smith'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release date': datetime.datetime(2013, 10, 22, 0, 0),
#   'Running time': 112,
#   'Country': 'United States',
#   'Language': 'English',
#   'Box Office (USD Millions)': 644.8,
#   'Budget (USD Millions)': 170.0,
#   'imdbRating': '6.9',
#   'Metascore': '54',
#   'Rotten Tomatoes': '66%'},
#  {'title': 'Captain America: The Winter Soldier',
#   'Directed by': ['Anthony Russo', 'Joe Russo'],
#   'Produced by': 'Kevin Feige',
#   'Screenplay by': ['Christopher Markus', 'Stephen McFeely'],
#   'Based on': ['Joe Simon', 'Jack Kirby'],
#   'Starring': ['Chris Evans',
#    'Scarlett Johansson',
#    'Sebastian Stan',
#    'Anthony Mackie',
#    'Cobie Smulders',
#    'Frank Grillo',
#    'Emily VanCamp',
#    'Hayley Atwell',
#    'Robert Redford',
#    'Samuel L. Jackson'],
#   'Music by': 'Henry Jackman',
#   'Cinematography': 'Trent Opaloch',
#   'Edited by': ['Jeffrey Ford', 'Matthew Schmidt'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release date': datetime.datetime(2014, 3, 13, 0, 0),
#   'Running time': 136,
#   'Country': 'United States',
#   'Language': 'English',
#   'Box Office (USD Millions)': 714.4,
#   'Budget (USD Millions)': 170.0,
#   'imdbRating': '7.7',
#   'Metascore': '70',
#   'Rotten Tomatoes': '90%'},
#  {'title': 'Avengers: Age of Ultron',
#   'Directed by': 'Joss Whedon',
#   'Produced by': 'Kevin Feige',
#   'Written by': 'Joss Whedon',
#   'Based on': ['Stan Lee', 'Jack Kirby'],
#   'Starring': ['Robert Downey Jr.',
#    'Chris Hemsworth',
#    'Mark Ruffalo',
#    'Chris Evans',
#    'Scarlett Johansson',
#    'Jeremy Renner',
#    'Don Cheadle',
#    'Aaron Taylor-Johnson',
#    'Elizabeth Olsen',
#    'Paul Bettany',
#    'Cobie Smulders',
#    'Anthony Mackie',
#    'Hayley Atwell',
#    'Idris Elba',
#    'Stellan SkarsgÃ¥rd',
#    'James Spader',
#    'Samuel L. Jackson'],
#   'Music by': ['Brian Tyler', 'Danny Elfman'],
#   'Cinematography': 'Ben Davis',
#   'Edited by': ['Jeffrey Ford', 'Lisa Lassek'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release date': datetime.datetime(2015, 4, 13, 0, 0),
#   'Running time': 141,
#   'Country': 'United States',
#   'Language': 'English',
#   'Box Office (USD Millions)': 1403.0,
#   'Budget (USD Millions)': 444.0,
#   'imdbRating': '7.3',
#   'Metascore': '66',
#   'Rotten Tomatoes': '76%'},
#  {'title': 'Ant-Man',
#   'Directed by': 'Peyton Reed',
#   'Produced by': 'Kevin Feige',
#   'Screenplay by': ['Edgar Wright', 'Joe Cornish', 'Adam McKay', 'Paul Rudd'],
#   'Story by': ['Edgar Wright', 'Joe Cornish'],
#   'Based on': ['Stan Lee', 'Larry Lieber', 'Jack Kirby'],
#   'Starring': ['Paul Rudd',
#    'Evangeline Lilly',
#    'Corey Stoll',
#    'Bobby Cannavale',
#    'Michael PeÃ±a',
#    'Tip "T.I." Harris',
#    'Anthony Mackie',
#    'Wood Harris',
#    'Judy Greer',
#    'David Dastmalchian',
#    'Michael Douglas'],
#   'Music by': 'Christophe Beck',
#   'Cinematography': 'Russell Carpenter',
#   'Edited by': ['Dan Lebental', 'Colby Parker, Jr.'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release date': datetime.datetime(2015, 6, 29, 0, 0),
#   'Running time': 117,
#   'Country': 'United States',
#   'Language': 'English',
#   'Box Office (USD Millions)': 519.3,
#   'Budget (USD Millions)': 130.0,
#   'imdbRating': '7.3',
#   'Metascore': '64',
#   'Rotten Tomatoes': '83%'},
#  {'title': 'Captain America: Civil War',
#   'Directed by': ['Anthony Russo Joe Russo', 'Anthony Russo', 'Joe Russo'],
#   'Produced by': 'Kevin Feige',
#   'Screenplay by': ['Christopher Markus Stephen McFeely',
#    'Christopher Markus',
#    'Stephen McFeely'],
#   'Based on': ['Joe Simon', 'Jack Kirby'],
#   'Starring': ['Chris Evans',
#    'Robert Downey Jr.',
#    'Scarlett Johansson',
#    'Sebastian Stan',
#    'Anthony Mackie',
#    'Don Cheadle',
#    'Jeremy Renner',
#    'Chadwick Boseman',
#    'Paul Bettany',
#    'Elizabeth Olsen',
#    'Paul Rudd',
#    'Emily VanCamp',
#    'Tom Holland',
#    'Frank Grillo',
#    'William Hurt',
#    'Daniel BrÃ¼hl'],
#   'Music by': 'Henry Jackman',
#   'Cinematography': 'Trent Opaloch',
#   'Edited by': ['Jeffrey Ford', 'Matthew Schmidt'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release date': datetime.datetime(2016, 4, 12, 0, 0),
#   'Running time': 147,
#   'Country': 'United States',
#   'Language': 'English',
#   'Box Office (USD Millions)': 1153.0,
#   'Budget (USD Millions)': 250.0,
#   'imdbRating': '7.8',
#   'Metascore': '75',
#   'Rotten Tomatoes': '91%'},
#  {'title': 'Doctor Strange',
#   'Directed by': 'Scott Derrickson',
#   'Produced by': 'Kevin Feige',
#   'Written by': ['Jon Spaihts', 'Scott Derrickson', 'C. Robert Cargill'],
#   'Based on': ['Stan Lee', 'Steve Ditko'],
#   'Starring': ['Benedict Cumberbatch',
#    'Chiwetel Ejiofor',
#    'Rachel McAdams',
#    'Benedict Wong',
#    'Michael Stuhlbarg',
#    'Benjamin Bratt',
#    'Scott Adkins',
#    'Mads Mikkelsen',
#    'Tilda Swinton'],
#   'Music by': 'Michael Giacchino',
#   'Cinematography': 'Ben Davis',
#   'Edited by': ['Wyatt Smith', 'Sabrina Plisco'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release date': datetime.datetime(2016, 10, 13, 0, 0),
#   'Running time': 115,
#   'Country': 'United States',
#   'Language': 'English',
#   'Box Office (USD Millions)': 677.7,
#   'Budget (USD Millions)': 165.0,
#   'imdbRating': '7.5',
#   'Metascore': '72',
#   'Rotten Tomatoes': '89%'},
#  {'title': 'Guardians of the Galaxy Vol. 2',
#   'Directed by': 'James Gunn',
#   'Produced by': 'Kevin Feige',
#   'Written by': 'James Gunn',
#   'Based on': ['Dan Abnett', 'Andy Lanning'],
#   'Starring': ['Chris Pratt',
#    'Zoe Saldana',
#    'Dave Bautista',
#    'Vin Diesel',
#    'Bradley Cooper',
#    'Michael Rooker',
#    'Karen Gillan',
#    'Pom Klementieff',
#    'Elizabeth Debicki',
#    'Chris Sullivan',
#    'Sean Gunn',
#    'Sylvester Stallone',
#    'Kurt Russell'],
#   'Music by': 'Tyler Bates',
#   'Cinematography': 'Henry Braham',
#   'Edited by': ['Fred Raskin', 'Craig Wood'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release date': datetime.datetime(2017, 4, 10, 0, 0),
#   'Running time': 137,
#   'Country': 'United States',
#   'Language': 'English',
#   'Box Office (USD Millions)': 863.8,
#   'Budget (USD Millions)': 200.0,
#   'imdbRating': '7.6',
#   'Metascore': '67',
#   'Rotten Tomatoes': '85%'},
#  {'title': 'Spider-Man: Homecoming',
#   'Directed by': 'Jon Watts',
#   'Produced by': ['Kevin Feige', 'Amy Pascal'],
#   'Screenplay by': ['Jonathan Goldstein',
#    'John Francis Daley',
#    'Jon Watts',
#    'Christopher Ford',
#    'Chris McKenna',
#    'Erik Sommers'],
#   'Story by': ['Jonathan Goldstein', 'John Francis Daley'],
#   'Based on': ['Stan Lee', 'Steve Ditko'],
#   'Starring': ['Tom Holland',
#    'Michael Keaton',
#    'Jon Favreau',
#    'Gwyneth Paltrow',
#    'Zendaya',
#    'Donald Glover',
#    'Jacob Batalon',
#    'Laura Harrier',
#    'Tony Revolori',
#    'Bokeem Woodbine',
#    'Tyne Daly',
#    'Marisa Tomei',
#    'Robert Downey Jr.'],
#   'Music by': 'Michael Giacchino',
#   'Cinematography': 'Salvatore Totino',
#   'Edited by': ['Dan Lebental', 'Debbie Berman'],
#   'Production companies': ['Columbia Pictures',
#    'Marvel Studios',
#    'Pascal Pictures'],
#   'Distributed by': 'Sony Pictures Releasing',
#   'Release date': datetime.datetime(2017, 6, 28, 0, 0),
#   'Running time': 133,
#   'Country': 'United States',
#   'Language': 'English',
#   'Box Office (USD Millions)': 880.2,
#   'Budget (USD Millions)': 175.0,
#   'imdbRating': '7.4',
#   'Metascore': '73',
#   'Rotten Tomatoes': '92%'},
#  {'title': 'Thor: Ragnarok',
#   'Directed by': 'Taika Waititi',
#   'Produced by': 'Kevin Feige',
#   'Written by': ['Eric Pearson', 'Craig Kyle', 'Christopher L. Yost'],
#   'Based on': ['Stan Lee', 'Larry Lieber', 'Jack Kirby'],
#   'Starring': ['Chris Hemsworth',
#    'Tom Hiddleston',
#    'Cate Blanchett',
#    'Idris Elba',
#    'Jeff Goldblum',
#    'Tessa Thompson',
#    'Karl Urban',
#    'Mark Ruffalo',
#    'Anthony Hopkins'],
#   'Music by': 'Mark Mothersbaugh',
#   'Cinematography': 'Javier Aguirresarobe',
#   'Edited by': ['Joel Negron', 'Zene Baker'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release date': datetime.datetime(2017, 10, 10, 0, 0),
#   'Running time': 130,
#   'Country': 'United States',
#   'Language': 'English',
#   'Box Office (USD Millions)': 854.0,
#   'Budget (USD Millions)': 180.0,
#   'imdbRating': '7.9',
#   'Metascore': '74',
#   'Rotten Tomatoes': '93%'},
#  {'title': 'Black Panther',
#   'Directed by': 'Ryan Coogler',
#   'Produced by': 'Kevin Feige',
#   'Written by': ['Ryan Coogler', 'Joe Robert Cole'],
#   'Based on': ['Stan Lee', 'Jack Kirby'],
#   'Starring': ['Chadwick Boseman',
#    'Michael B. Jordan',
#    "Lupita Nyong'o",
#    'Danai Gurira',
#    'Martin Freeman',
#    'Daniel Kaluuya',
#    'Letitia Wright',
#    'Winston Duke',
#    'Angela Bassett',
#    'Forest Whitaker',
#    'Andy Serkis'],
#   'Music by': 'Ludwig GÃ¶ransson',
#   'Cinematography': 'Rachel Morrison',
#   'Edited by': ['Michael P. Shawver', 'Debbie Berman'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release date': datetime.datetime(2018, 1, 29, 0, 0),
#   'Running time': 134,
#   'Country': 'United States',
#   'Language': 'English',
#   'Box Office (USD Millions)': 1347.0,
#   'Budget (USD Millions)': 200.0,
#   'imdbRating': '7.3',
#   'Metascore': '88',
#   'Rotten Tomatoes': '96%'},
#  {'title': 'Avengers: Infinity War',
#   'Directed by': ['Anthony Russo', 'Joe Russo'],
#   'Produced by': 'Kevin Feige',
#   'Screenplay by': ['Christopher Markus', 'Stephen McFeely'],
#   'Based on': ['Stan Lee', 'Jack Kirby'],
#   'Starring': ['Robert Downey Jr.',
#    'Chris Hemsworth',
#    'Mark Ruffalo',
#    'Chris Evans',
#    'Scarlett Johansson',
#    'Benedict Cumberbatch',
#    'Don Cheadle',
#    'Tom Holland',
#    'Chadwick Boseman',
#    'Paul Bettany',
#    'Elizabeth Olsen',
#    'Anthony Mackie',
#    'Sebastian Stan',
#    'Danai Gurira',
#    'Letitia Wright',
#    'Dave Bautista',
#    'Zoe Saldana',
#    'Josh Brolin',
#    'Chris Pratt'],
#   'Music by': 'Alan Silvestri',
#   'Cinematography': 'Trent Opaloch',
#   'Edited by': ['Jeffrey Ford', 'Matthew Schmidt'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release date': datetime.datetime(2018, 4, 23, 0, 0),
#   'Running time': 149,
#   'Country': 'United States',
#   'Language': 'English',
#   'Box Office (USD Millions)': 2048.0,
#   'Budget (USD Millions)': 316.0,
#   'imdbRating': '8.4',
#   'Metascore': '68',
#   'Rotten Tomatoes': '85%'},
#  {'title': 'Ant-Man and the Wasp',
#   'Directed by': 'Peyton Reed',
#   'Produced by': ['Kevin Feige', 'Stephen Broussard'],
#   'Written by': ['Chris McKenna',
#    'Erik Sommers',
#    'Paul Rudd',
#    'Andrew Barrer',
#    'Gabriel Ferrari'],
#   'Based on': ['Ant-Man by Stan Lee Larry Lieber Jack Kirby',
#    'Stan Lee',
#    'Larry Lieber',
#    'Jack Kirby',
#    'Wasp by Stan Lee Ernie Hart Jack Kirby',
#    'Stan Lee',
#    'Ernie Hart',
#    'Jack Kirby'],
#   'Starring': ['Paul Rudd',
#    'Evangeline Lilly',
#    'Michael PeÃ±a',
#    'Walton Goggins',
#    'Bobby Cannavale',
#    'Judy Greer',
#    'Tip "T.I." Harris',
#    'David Dastmalchian',
#    'Hannah John-Kamen',
#    'Abby Ryder Fortson',
#    'Randall Park',
#    'Michelle Pfeiffer',
#    'Laurence Fishburne',
#    'Michael Douglas'],
#   'Music by': 'Christophe Beck',
#   'Cinematography': 'Dante Spinotti',
#   'Edited by': ['Dan Lebental', 'Craig Wood'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release date': datetime.datetime(2018, 6, 25, 0, 0),
#   'Running time': 118,
#   'Country': 'United States',
#   'Language': 'English',
#   'Box Office (USD Millions)': 622.7,
#   'Budget (USD Millions)': 162.0,
#   'imdbRating': '7.1',
#   'Metascore': '70',
#   'Rotten Tomatoes': '87%'},
#  {'title': 'Captain Marvel',
#   'Directed by': ['Anna Boden', 'Ryan Fleck'],
#   'Produced by': 'Kevin Feige',
#   'Screenplay by': ['Anna Boden', 'Ryan Fleck', 'Geneva Robertson-Dworet'],
#   'Story by': ['Nicole Perlman',
#    'Meg LeFauve',
#    'Anna Boden',
#    'Ryan Fleck',
#    'Geneva Robertson-Dworet'],
#   'Based on': ['Captain Marvel by Stan Lee Gene Colan',
#    'Stan Lee',
#    'Gene Colan',
#    'Carol Danvers by Roy Thomas Gene Colan',
#    'Roy Thomas',
#    'Gene Colan'],
#   'Starring': ['Brie Larson',
#    'Samuel L. Jackson',
#    'Ben Mendelsohn',
#    'Djimon Hounsou',
#    'Lee Pace',
#    'Lashana Lynch',
#    'Gemma Chan',
#    'Annette Bening',
#    'Clark Gregg',
#    'Jude Law'],
#   'Music by': 'Pinar Toprak',
#   'Cinematography': 'Ben Davis',
#   'Edited by': ['Elliot Graham', 'Debbie Berman'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release date': datetime.datetime(2019, 2, 27, 0, 0),
#   'Running time': 124,
#   'Country': 'United States',
#   'Language': 'English',
#   'Box Office (USD Millions)': 1128.0,
#   'Budget (USD Millions)': 152.0,
#   'imdbRating': '6.9',
#   'Metascore': '64',
#   'Rotten Tomatoes': '79%'},
#  {'title': 'Avengers: Endgame',
#   'Directed by': ['Anthony Russo', 'Joe Russo'],
#   'Produced by': 'Kevin Feige',
#   'Screenplay by': ['Christopher Markus', 'Stephen McFeely'],
#   'Based on': ['Stan Lee', 'Jack Kirby'],
#   'Starring': ['Robert Downey Jr.',
#    'Chris Evans',
#    'Mark Ruffalo',
#    'Chris Hemsworth',
#    'Scarlett Johansson',
#    'Jeremy Renner',
#    'Don Cheadle',
#    'Paul Rudd',
#    'Brie Larson',
#    'Karen Gillan',
#    'Danai Gurira',
#    'Benedict Wong',
#    'Jon Favreau',
#    'Bradley Cooper',
#    'Gwyneth Paltrow',
#    'Josh Brolin'],
#   'Music by': 'Alan Silvestri',
#   'Cinematography': 'Trent Opaloch',
#   'Edited by': ['Jeffrey Ford', 'Matthew Schmidt'],
#   'Production company': 'Marvel Studios',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release date': datetime.datetime(2019, 4, 22, 0, 0),
#   'Running time': 181,
#   'Country': 'United States',
#   'Language': 'English',
#   'Box Office (USD Millions)': 2798.0,
#   'Budget (USD Millions)': 356.0,
#   'imdbRating': '8.4',
#   'Metascore': '78',
#   'Rotten Tomatoes': '94%'},
#  {'title': 'Spider-Man: Far From Home',
#   'Directed by': 'Jon Watts',
#   'Produced by': ['Kevin Feige', 'Amy Pascal'],
#   'Written by': ['Chris McKenna', 'Erik Sommers'],
#   'Based on': ['Stan Lee', 'Steve Ditko'],
#   'Starring': ['Tom Holland',
#    'Samuel L. Jackson',
#    'Zendaya',
#    'Cobie Smulders',
#    'Jon Favreau',
#    'J. B. Smoove',
#    'Jacob Batalon',
#    'Martin Starr',
#    'Marisa Tomei',
#    'Jake Gyllenhaal'],
#   'Music by': 'Michael Giacchino',
#   'Cinematography': 'Matthew J. Lloyd',
#   'Edited by': ['Dan Lebental', 'Leigh Folsom Boyd'],
#   'Production companies': ['Columbia Pictures',
#    'Marvel Studios',
#    'Pascal Pictures'],
#   'Distributed by': 'Sony Pictures Releasing',
#   'Release date': datetime.datetime(2019, 6, 26, 0, 0),
#   'Running time': 129,
#   'Country': 'United States',
#   'Language': 'English',
#   'Box Office (USD Millions)': 1132.0,
#   'Budget (USD Millions)': 160.0,
#   'imdbRating': '7.5',
#   'Metascore': '69',
#   'Rotten Tomatoes': '90%'}]

# %% [markdown]
# ### Save Data as JSON & CSV

# %%
movie_info_copy = [movie.copy() for movie in movie_info_list]

# %%
for movie in movie_info_copy :
    movie['Release date'] = movie['Release date'].strftime('%B %d, %Y')

# %%
save_data('marvel_movie_data_final.json',movie_info_copy)

# %%
movie_info_copy = load_data('marvel_movie_data_final.json')

# %%
df = pd.DataFrame(movie_info_list)

# %%
df
# Out:
#                                   title  \
# 0                              Iron Man
# 1                   The Incredible Hulk
# 2                            Iron Man 2
# 3    Captain America: The First Avenger
# 4                          The Avengers
# 5                            Iron Man 3
# 6                  Thor: The Dark World
# 7   Captain America: The Winter Soldier
# 8               Avengers: Age of Ultron
# 9                               Ant-Man
# 10           Captain America: Civil War
# 11                       Doctor Strange
# 12       Guardians of the Galaxy Vol. 2
# 13               Spider-Man: Homecoming
# 14                       Thor: Ragnarok
# 15                        Black Panther
# 16               Avengers: Infinity War
# 17                 Ant-Man and the Wasp
# 18                       Captain Marvel
# 19                    Avengers: Endgame
# 20            Spider-Man: Far From Home
#
#                                           Directed by  \
# 0                                         Jon Favreau
# 1                                     Louis Leterrier
# 2                                         Jon Favreau
# 3                                        Joe Johnston
# 4                                         Joss Whedon
# 5                                         Shane Black
# 6                                         Alan Taylor
# 7                          [Anthony Russo, Joe Russo]
# 8                                         Joss Whedon
# 9                                         Peyton Reed
# 10  [Anthony Russo Joe Russo, Anthony Russo, Joe R...
# 11                                   Scott Derrickson
# 12                                         James Gunn
# 13                                          Jon Watts
# 14                                      Taika Waititi
# 15                                       Ryan Coogler
# 16                         [Anthony Russo, Joe Russo]
# 17                                        Peyton Reed
# 18                           [Anna Boden, Ryan Fleck]
# 19                         [Anthony Russo, Joe Russo]
# 20                                          Jon Watts
#
#                                 Produced by  \
# 0                   [Avi Arad, Kevin Feige]
# 1   [Avi Arad, Gale Anne Hurd, Kevin Feige]
# 2                               Kevin Feige
# 3                               Kevin Feige
# 4                               Kevin Feige
# 5                               Kevin Feige
# 6                               Kevin Feige
# 7                               Kevin Feige
# 8                               Kevin Feige
# 9                               Kevin Feige
# 10                              Kevin Feige
# 11                              Kevin Feige
# 12                              Kevin Feige
# 13                [Kevin Feige, Amy Pascal]
# 14                              Kevin Feige
# 15                              Kevin Feige
# 16                              Kevin Feige
# 17         [Kevin Feige, Stephen Broussard]
# 18                              Kevin Feige
# 19                              Kevin Feige
# 20                [Kevin Feige, Amy Pascal]
#
#                                         Screenplay by  \
# 0   [Mark Fergus Hawk Ostby, Art Marcum Matt Hollo...
# 1                                                 NaN
# 2                                                 NaN
# 3                  Christopher Markus Stephen McFeely
# 4                                         Joss Whedon
# 5                          [Shane Black, Drew Pearce]
# 6   [Christopher Yost, Christopher Markus Stephen ...
# 7               [Christopher Markus, Stephen McFeely]
# 8                                                 NaN
# 9   [Edgar Wright, Joe Cornish, Adam McKay, Paul R...
# 10  [Christopher Markus Stephen McFeely, Christoph...
# 11                                                NaN
# 12                                                NaN
# 13  [Jonathan Goldstein, John Francis Daley, Jon W...
# 14                                                NaN
# 15                                                NaN
# 16              [Christopher Markus, Stephen McFeely]
# 17                                                NaN
# 18  [Anna Boden, Ryan Fleck, Geneva Robertson-Dworet]
# 19              [Christopher Markus, Stephen McFeely]
# 20                                                NaN
#
#                                              Based on  \
# 0      [Stan Lee, Larry Lieber, Don Heck, Jack Kirby]
# 1                              [Stan Lee, Jack Kirby]
# 2      [Stan Lee, Larry Lieber, Don Heck, Jack Kirby]
# 3                             [Joe Simon, Jack Kirby]
# 4                              [Stan Lee, Jack Kirby]
# 5      [Stan Lee, Don Heck, Larry Lieber, Jack Kirby]
# 6                [Stan Lee, Larry Lieber, Jack Kirby]
# 7                             [Joe Simon, Jack Kirby]
# 8                              [Stan Lee, Jack Kirby]
# 9                [Stan Lee, Larry Lieber, Jack Kirby]
# 10                            [Joe Simon, Jack Kirby]
# 11                            [Stan Lee, Steve Ditko]
# 12                         [Dan Abnett, Andy Lanning]
# 13                            [Stan Lee, Steve Ditko]
# 14               [Stan Lee, Larry Lieber, Jack Kirby]
# 15                             [Stan Lee, Jack Kirby]
# 16                             [Stan Lee, Jack Kirby]
# 17  [Ant-Man by Stan Lee Larry Lieber Jack Kirby, ...
# 18  [Captain Marvel by Stan Lee Gene Colan, Stan L...
# 19                             [Stan Lee, Jack Kirby]
# 20                            [Stan Lee, Steve Ditko]
#
#                                              Starring  \
# 0   [Robert Downey Jr., Terrence Howard, Jeff Brid...
# 1   [Edward Norton, Liv Tyler, Tim Roth, Tim Blake...
# 2   [Robert Downey Jr., Gwyneth Paltrow, Don Chead...
# 3   [Chris Evans, Tommy Lee Jones, Hugo Weaving, H...
# 4   [Robert Downey Jr., Chris Evans, Mark Ruffalo,...
# 5   [Robert Downey Jr., Gwyneth Paltrow, Don Chead...
# 6   [Chris Hemsworth, Natalie Portman, Tom Hiddles...
# 7   [Chris Evans, Scarlett Johansson, Sebastian St...
# 8   [Robert Downey Jr., Chris Hemsworth, Mark Ruff...
# 9   [Paul Rudd, Evangeline Lilly, Corey Stoll, Bob...
# 10  [Chris Evans, Robert Downey Jr., Scarlett Joha...
# 11  [Benedict Cumberbatch, Chiwetel Ejiofor, Rache...
# 12  [Chris Pratt, Zoe Saldana, Dave Bautista, Vin ...
# 13  [Tom Holland, Michael Keaton, Jon Favreau, Gwy...
# 14  [Chris Hemsworth, Tom Hiddleston, Cate Blanche...
# 15  [Chadwick Boseman, Michael B. Jordan, Lupita N...
# 16  [Robert Downey Jr., Chris Hemsworth, Mark Ruff...
# 17  [Paul Rudd, Evangeline Lilly, Michael PeÃ±a, W...
# 18  [Brie Larson, Samuel L. Jackson, Ben Mendelsoh...
# 19  [Robert Downey Jr., Chris Evans, Mark Ruffalo,...
# 20  [Tom Holland, Samuel L. Jackson, Zendaya, Cobi...
#
#                        Music by        Cinematography  \
# 0                 Ramin Djawadi     Matthew Libatique
# 1               Craig Armstrong     Peter Menzies Jr.
# 2                   John Debney     Matthew Libatique
# 3                Alan Silvestri        Shelly Johnson
# 4                Alan Silvestri       Seamus McGarvey
# 5                   Brian Tyler             John Toll
# 6                   Brian Tyler     Kramer Morgenthau
# 7                 Henry Jackman         Trent Opaloch
# 8   [Brian Tyler, Danny Elfman]             Ben Davis
# 9               Christophe Beck     Russell Carpenter
# 10                Henry Jackman         Trent Opaloch
# 11            Michael Giacchino             Ben Davis
# 12                  Tyler Bates          Henry Braham
# 13            Michael Giacchino      Salvatore Totino
# 14            Mark Mothersbaugh  Javier Aguirresarobe
# 15            Ludwig GÃ¶ransson       Rachel Morrison
# 16               Alan Silvestri         Trent Opaloch
# 17              Christophe Beck        Dante Spinotti
# 18                 Pinar Toprak             Ben Davis
# 19               Alan Silvestri         Trent Opaloch
# 20            Michael Giacchino      Matthew J. Lloyd
#
#                                         Edited by  \
# 0                                    Dan Lebental
# 1   [John Wright, Rick Shaine, Vincent Tabaillon]
# 2                 [Dan Lebental, Richard Pearson]
# 3                    [Jeffrey Ford, Robert Dalva]
# 4                     [Jeffrey Ford, Lisa Lassek]
# 5                 [Jeffrey Ford, Peter S. Elliot]
# 6                     [Dan Lebental, Wyatt Smith]
# 7                 [Jeffrey Ford, Matthew Schmidt]
# 8                     [Jeffrey Ford, Lisa Lassek]
# 9               [Dan Lebental, Colby Parker, Jr.]
# 10                [Jeffrey Ford, Matthew Schmidt]
# 11                  [Wyatt Smith, Sabrina Plisco]
# 12                      [Fred Raskin, Craig Wood]
# 13                  [Dan Lebental, Debbie Berman]
# 14                      [Joel Negron, Zene Baker]
# 15            [Michael P. Shawver, Debbie Berman]
# 16                [Jeffrey Ford, Matthew Schmidt]
# 17                     [Dan Lebental, Craig Wood]
# 18                 [Elliot Graham, Debbie Berman]
# 19                [Jeffrey Ford, Matthew Schmidt]
# 20              [Dan Lebental, Leigh Folsom Boyd]
#
#                             Production company  ...        Country Language  \
# 0                               Marvel Studios  ...  United States  English
# 1   [Marvel Studios, Valhalla Motion Pictures]  ...  United States  English
# 2                               Marvel Studios  ...  United States  English
# 3                               Marvel Studios  ...  United States  English
# 4                               Marvel Studios  ...  United States  English
# 5                               Marvel Studios  ...  United States  English
# 6                               Marvel Studios  ...  United States  English
# 7                               Marvel Studios  ...  United States  English
# 8                               Marvel Studios  ...  United States  English
# 9                               Marvel Studios  ...  United States  English
# 10                              Marvel Studios  ...  United States  English
# 11                              Marvel Studios  ...  United States  English
# 12                              Marvel Studios  ...  United States  English
# 13                                         NaN  ...  United States  English
# 14                              Marvel Studios  ...  United States  English
# 15                              Marvel Studios  ...  United States  English
# 16                              Marvel Studios  ...  United States  English
# 17                              Marvel Studios  ...  United States  English
# 18                              Marvel Studios  ...  United States  English
# 19                              Marvel Studios  ...  United States  English
# 20                                         NaN  ...  United States  English
#
#     Box Office (USD Millions) Budget (USD Millions) imdbRating  Metascore  \
# 0                       585.3                 140.0        7.9         79
# 1                       264.8                 150.0        6.7         61
# 2                       623.9                 170.0        7.0         57
# 3                       370.6                 140.0        6.9         66
# 4                      1519.0                 220.0        8.0         69
# 5                      1215.0                 200.0        7.2         62
# 6                       644.8                 170.0        6.9         54
# 7                       714.4                 170.0        7.7         70
# 8                      1403.0                 444.0        7.3         66
# 9                       519.3                 130.0        7.3         64
# 10                     1153.0                 250.0        7.8         75
# 11                      677.7                 165.0        7.5         72
# 12                      863.8                 200.0        7.6         67
# 13                      880.2                 175.0        7.4         73
# 14                      854.0                 180.0        7.9         74
# 15                     1347.0                 200.0        7.3         88
# 16                     2048.0                 316.0        8.4         68
# 17                      622.7                 162.0        7.1         70
# 18                     1128.0                 152.0        6.9         64
# 19                     2798.0                 356.0        8.4         78
# 20                     1132.0                 160.0        7.5         69
#
#     Rotten Tomatoes                                         Written by  \
# 0               94%                                                NaN
# 1               67%                                           Zak Penn
# 2               72%                                     Justin Theroux
# 3               80%                                                NaN
# 4               92%                                                NaN
# 5               79%                                                NaN
# 6               66%                                                NaN
# 7               90%                                                NaN
# 8               76%                                        Joss Whedon
# 9               83%                                                NaN
# 10              91%                                                NaN
# 11              89%  [Jon Spaihts, Scott Derrickson, C. Robert Carg...
# 12              85%                                         James Gunn
# 13              92%                                                NaN
# 14              93%    [Eric Pearson, Craig Kyle, Christopher L. Yost]
# 15              96%                    [Ryan Coogler, Joe Robert Cole]
# 16              85%                                                NaN
# 17              87%  [Chris McKenna, Erik Sommers, Paul Rudd, Andre...
# 18              79%                                                NaN
# 19              94%                                                NaN
# 20              90%                      [Chris McKenna, Erik Sommers]
#
#                                              Story by  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                             [Zak Penn, Joss Whedon]
# 5                                                 NaN
# 6                           [Don Payne, Robert Rodat]
# 7                                                 NaN
# 8                                                 NaN
# 9                         [Edgar Wright, Joe Cornish]
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13           [Jonathan Goldstein, John Francis Daley]
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  [Nicole Perlman, Meg LeFauve, Anna Boden, Ryan...
# 19                                                NaN
# 20                                                NaN
#
#                                  Production companies
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  [Columbia Pictures, Marvel Studios, Pascal Pic...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20  [Columbia Pictures, Marvel Studios, Pascal Pic...
#
# [21 rows x 23 columns]

# %%
df.to_csv('marvel_movie_data_final.csv')
